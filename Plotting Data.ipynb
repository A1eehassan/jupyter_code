# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
sns.set()

# %%
heart = pd.read_csv('heart.csv')
heart
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# ...

# %%
over_30 = heart[heart['age']>30]
over_30
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# ...

# %%
over_30.plot(kind = 'scatter',
             x = 'age',
             y = 'chol',
             c = 'output');

# %%
fig,(plot1,plot2) = plt.subplots(nrows = 2, 
                                 ncols = 1, 
                                 figsize = (10,10),
                                 sharex = True )
fig.suptitle('Patients Data', fontsize = 32, fontweight = 'bold');
scatter_plot1 = plot1.scatter(x = over_40['age'],
                              y = over_40['chol'],
                              c = over_40['output'],
                              cmap = 'plasma')
plot1.set(title = 'heart diseases with cholesterol',
          ylabel = 'cholesterol')
          
plot1.legend(*scatter_plot1.legend_elements(), title = 'Survived/Not Survived')
plot1.axhline(y = over_40['chol'].mean(),linestyle = '--')
scatter_plot1;
scatter_plot2 = plot2.scatter(x = over_40['age'],
                              y = over_40['thalachh'],
                              c = over_40['output'],
                              cmap = 'plasma')
plot2.set(title = 'heart diseases',
          xlabel = 'age',
          ylabel = 'thalachh')
plot2.legend(*scatter_plot1.legend_elements(), title = 'Survived/Not Survived')
plot2.axhline(y = over_40['thalachh'].mean(),linestyle = '--')
scatter_plot2;
fig.savefig('Patients Data Reports.png')
